# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid19= pd.read_csv('COVID clinical trials.csv')
type(covid19)
# Out:
# pandas.core.frame.DataFrame

# %%
covid19.shape
# Out:
# (5783, 27)

# %%
covid19.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
covid19.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
covid19.tail(n=10)
# Out:
#       Rank   NCT Number                                              Title  \
# 5773  5774  NCT04639661  Predictors of Periodontal Outcomes Post-sanati...
# 5774  5775  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
# 5775  5776  NCT04335643  Telehealth CBT for Adolescents and Young Adult...
# 5776  5777  NCT04589377  Mindfulness to Mitigate Psychological Threat a...
# 5777  5778  NCT04574466  Scaling-up Psychological Interventions With Sy...
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5779  5780  NCT04681339  Antibiotic Prescription in Children Hospitaliz...
# 5780  5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5781  5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
# 5782  5783  NCT04680000  Chronic Pain Management In Primary Care Using ...
#
#            Acronym                   Status         Study Results  \
# 5773           NaN  Enrolling by invitation  No Results Available
# ...

# %%
covid19.dtypes
# Out:
# Rank                         int64
# NCT Number                  object
# Title                       object
# Acronym                     object
# Status                      object
# Study Results               object
# Conditions                  object
# Interventions               object
# Outcome Measures            object
# Sponsor/Collaborators       object
# Gender                      object
# Age                         object
# Phases                      object
# Enrollment                 float64
# Funded Bys                  object
# Study Type                  object
# Study Designs               object
# Other IDs                   object
# Start Date                  object
# Primary Completion Date     object
# Completion Date             object
# First Posted                object
# Results First Posted        object
# Last Update Posted          object
# Locations                   object
# Study Documents             object
# URL                         object
# ...

# %%
covid19.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %%
covid19.isnull().mean()*100
# Out:
# Rank                        0.000000
# NCT Number                  0.000000
# Title                       0.000000
# Acronym                    57.115684
# Status                      0.000000
# Study Results               0.000000
# Conditions                  0.000000
# Interventions              15.320768
# Outcome Measures            0.605222
# Sponsor/Collaborators       0.000000
# Gender                      0.172921
# Age                         0.000000
# Phases                     42.555767
# Enrollment                  0.587930
# Funded Bys                  0.000000
# Study Type                  0.000000
# Study Designs               0.605222
# Other IDs                   0.017292
# Start Date                  0.587930
# Primary Completion Date     0.622514
# Completion Date             0.622514
# First Posted                0.000000
# Results First Posted       99.377486
# Last Update Posted          0.000000
# Locations                  10.115857
# ...

# %%
qty_of_nuls = 11
covid19.iloc[covid19[(covid19.isnull().sum(axis=1) >=qty_of_nuls)].index]
# Out:
#       Rank   NCT Number                                              Title  \
# 1924  1925  NCT04355793  Expanded Access Program of Ruxolitinib for the...
# 2380  2381  NCT04363034  Arkansas Expanded Access COVID-19 Convalescent...
# 2767  2768  NCT04802083          COVID-19 Soliris Expanded Access Protocol
# 3457  3458  NCT04337359  Ruxolitinib Managed Access Program (MAP) for P...
# 3547  3548  NCT04476706     Canakinumab MAP in COVID-19 Pneumonia With CRS
# 3767  3768  NCT04456439  Intermediate-size Expanded Access Program (EAP...
# 3910  3911  NCT04657458  Expanded Access Protocol on Bone Marrow Mesenc...
# 3914  3915  NCT04636554  Personalized Phage Treatment in Covid-19 Patie...
# 3956  3957  NCT04358588  Pulsed Inhaled Nitric Oxide for the Treatment ...
# 4427  4428  NCT04657406  Expanded Access to ZofinTM (OrganicellTM Flow)...
# 4530  4531  NCT04617535  Compassionate Use of REGN-COV2 for the Treatme...
# ...

# %%
covid19.drop("Results First Posted",axis=1,inplace= True)

# %%
covid19.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Last Update Posted', 'Locations', 'Study Documents', 'URL'],
#       dtype='object')

# %%
covid19.drop("Study Documents", axis=1,inplace=True)

# %%
covid19.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Last Update Posted', 'Locations', 'URL'],
#       dtype='object')

# %%
covid19.isnull().mean()*100
# Out:
# Rank                        0.000000
# NCT Number                  0.000000
# Title                       0.000000
# Acronym                    57.115684
# Status                      0.000000
# Study Results               0.000000
# Conditions                  0.000000
# Interventions              15.320768
# Outcome Measures            0.605222
# Sponsor/Collaborators       0.000000
# Gender                      0.172921
# Age                         0.000000
# Phases                     42.555767
# Enrollment                  0.587930
# Funded Bys                  0.000000
# Study Type                  0.000000
# Study Designs               0.605222
# Other IDs                   0.017292
# Start Date                  0.587930
# Primary Completion Date     0.622514
# Completion Date             0.622514
# First Posted                0.000000
# Last Update Posted          0.000000
# Locations                  10.115857
# URL                         0.000000
# dtype: float64

# %%
covid19.Acronym = covid19.Acronym.fillna('DataLost')

# %%
covid19.head(n=12)
# Out:
#     Rank   NCT Number                                              Title  \
# 0      1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1      2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2      3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3      4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4      5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 5      6  NCT04516954          Convalescent Plasma for COVID-19 Patients
# 6      7  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 7      8  NCT04634214  The Severity of COVID 19 in Diabetes and Non-d...
# 8      9  NCT04602884  Early Detection of COVID-19 Using Breath Analysis
# 9     10  NCT04384588  COVID19-Convalescent Plasma for Treating Patie...
# 10    11  NCT04355897  CoVID-19 Plasma in Treatment of COVID-19 Patients
# 11    12  NCT04412265          Frailty in Elderly Patients With COVID-19
#
# ...

# %%
covid19.Enrollment.nunique(dropna= True)
# Out:
# 962

# %%
print(covid19['Enrollment'])
# Out:
# 0       1000.0
# 1         60.0
# 2        500.0
# 3       2500.0
# 4         50.0
#          ...
# 5778     566.0
# 5779     200.0
# 5780      88.0
# 5781     396.0
# 5782     716.0
# Name: Enrollment, Length: 5783, dtype: float64

# %%
maxenro= covid19['Enrollment'].max()
minenro= covid19['Enrollment'].min()

print('Maximun value in column Enrollment : ', maxenro)
print('Minimun value in column Enrollment : ', minenro)
# Out:
# Maximun value in column Enrollment :  20000000.0
# Minimun value in column Enrollment :  0.0

# %%
x=covid19['Enrollment'].median()
y=covid19['Enrollment'].mode()
z=covid19['Enrollment'].std()

print(x)
print(y)
print(z)
# Out:
# 170.0
# 0    100.0
# Name: Enrollment, dtype: float64
# 404543.7287841073

# %%
y=covid19['Enrollment'].sort_values(ascending=True);
median=y.median()

print(median)
# Out:
# 170.0

# %%
covid19.Enrollment = covid19.Enrollment.fillna(x)

# %%
covid19[['Start Date', 'Primary Completion Date']] = covid19[['Start Date','Primary Completion Date']].fillna('Data Not Found')
covid19['Completion Date'] = covid19['Completion Date'].fillna('Data Not Found')

# %%
covid19.Gender = covid19.Gender.fillna('Not Recorded')

# %%
covid19[['Phases', 'Locations']] = covid19[['Phases','Locations']].fillna('Unknown')

# %%
covid19=covid19.fillna(value='Unknown/Other')

# %%
covid19.isnull().sum()
# Out:
# Rank                       0
# NCT Number                 0
# Title                      0
# Acronym                    0
# Status                     0
# Study Results              0
# Conditions                 0
# Interventions              0
# Outcome Measures           0
# Sponsor/Collaborators      0
# Gender                     0
# Age                        0
# Phases                     0
# Enrollment                 0
# Funded Bys                 0
# Study Type                 0
# Study Designs              0
# Other IDs                  0
# Start Date                 0
# Primary Completion Date    0
# Completion Date            0
# First Posted               0
# Last Update Posted         0
# Locations                  0
# URL                        0
# dtype: int64

# %%
covid19.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Last Update Posted', 'Locations', 'URL'],
#       dtype='object')

# %%
covid19['Study Type'].value_counts().sort_values(ascending=True).plot(kind='barh',color='red')
# Out:
# <AxesSubplot:>

# %%
covid19['Phases'].value_counts().sort_values(ascending=True).plot(kind='barh',color='yellow')
# Out:
# <AxesSubplot:>

# %%
covid19.plot(kind='scatter', x='Phases', y='Enrollment', \
        color='dodgerblue', figsize=(15,4), s=10)
# Out:
# <AxesSubplot:xlabel='Phases', ylabel='Enrollment'>

# %%
ph = sns.barplot(x="Enrollment",y="Phases",data=covid19)
plt.show()

# %%
covid19.plot(kind='line', x='Conditions', y='Enrollment')
# Out:
# <AxesSubplot:xlabel='Conditions'>

# %%
covid19['Enrollment'].value_counts().sort_index().plot();

# %%
covid19.Gender.unique()
# Out:
# array(['All', 'Female', 'Male', 'Not Recorded'], dtype=object)

# %%
covid19['Gender'].value_counts().head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
covid19.Age.unique()
# Out:
# array(['18 Years and older \xa0 (Adult, Older Adult)',
#        'Child, Adult, Older Adult', '18 Years to 48 Years \xa0 (Adult)',
#        '18 Years to 75 Years \xa0 (Adult, Older Adult)',
#        '18 Years to 45 Years \xa0 (Adult)',
#        '18 Years to 99 Years \xa0 (Adult, Older Adult)',
#        '18 Years to 55 Years \xa0 (Adult)',
#        '15 Years and older \xa0 (Child, Adult, Older Adult)',
#        '18 Years to 80 Years \xa0 (Adult, Older Adult)',
#        '45 Years and older \xa0 (Adult, Older Adult)',
#        '20 Years to 100 Years \xa0 (Adult, Older Adult)',
#        '8 Years to 88 Years \xa0 (Child, Adult, Older Adult)',
#        '5 Years to 65 Years \xa0 (Child, Adult, Older Adult)',
#        'up to 99 Years \xa0 (Child, Adult, Older Adult)',
#        '18 Years to 85 Years \xa0 (Adult, Older Adult)',
#        '18 Years to 65 Years \xa0 (Adult, Older Adult)',
#        'up to 29 Days \xa0 (Child)',
#        '18 Years to 70 Years \xa0 (Adult, Older Adult)',
# ...

# %%
covid19['Age'].value_counts().head().plot(kind='bar')
plt.rcParams["figure.figsize"] = (45,15)

# %%
ge = sns.lineplot(x="Gender", y="Enrollment", data=covid19)
plt.show()

# %%
covid19['Age'].value_counts().sort_index().plot()
plt.rcParams["figure.figsize"] = (25,15)
